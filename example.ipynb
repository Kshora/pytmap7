# %%
# %matplotlib inline
from matplotlib.pylab import *
import pandas as pd

# %%
# %run -n tmap7.py

# %%
t = np.linspace(0,300,300)
p = np.linspace(1,1,300)
p[250:] = 0
plot(t,p)

# %%
writePirani((t,p),'pirani.dat')

# %%
p = pd.read_csv('pirani.dat',names=['time','p'])
plot(p['time'],p['p'])

# %% [markdown]
# # run TMAP7 with `pirani.dat` as an inmput file
# `runT7(amplitude, ku, kd, time step for T7, input concentration) `
#
# Make sure that you have correct paths to TMAP7 folder, and copy `.bat` files from this project to TMAP7 folder

# %%
# %run -n tmap7.py

t,gamma = runT7(1.e18,1e-30,1e-30,tstep=0.2,pfile='pirani.dat')
plt.plot(t,gamma,label = 'fit')
